# %% [markdown]
# # Problem definition
#
# Create some data, in this case a parabola plus white noise:

# %%
using Plots
gr(size=(1000,500))

srand(2017)

N = 100
x = linspace(0,1, N)
y = x.^2 .+ [i/1000*randn() for i=1:N]

scatter(x, y, label="data")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="1000" height="500" viewBox="0 0 1000 500">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="1000" height="500"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8900)" points="
# 0,500 1000,500 1000,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="200" y="0" width="701" height="500"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8900)" points="
# 32.2221,475.813 980.315,475.813 980.315,11.811 32.2221,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="32" y="11" width="949" height="465"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.0549,468.853 59.0549,18.7711
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   282.662,468.853 282.662,18.7711
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   506.269,468.853 506.269,18.7711
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   729.875,468.853 729.875,18.7711
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   953.482,468.853 953.482,18.7711
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.4435,459.589 966.094,459.589
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.4435,388.62 966.094,388.62
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.4435,317.652 966.094,317.652
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.4435,246.683 966.094,246.683
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.4435,175.714 966.094,175.714
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.4435,104.746 966.094,104.746
#   "/>
# <polyline clip-path="url(#clip8902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.4435,33.7769 966.094,33.7769
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,475.813 980.315,475.813
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,475.813 32.2221,11.811
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   59.0549,475.813 59.0549,468.853
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   282.662,475.813 282.662,468.853
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   506.269,475.813 506.269,468.853
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   729.875,475.813 729.875,468.853
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   953.482,475.813 953.482,468.853
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,459.589 46.4435,459.589
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,388.62 46.4435,388.62
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,317.652 46.4435,317.652
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,246.683 46.4435,246.683
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,175.714 46.4435,175.714
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,104.746 46.4435,104.746
#   "/>
# <polyline clip-path="url(#clip8900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,33.7769 46.4435,33.7769
#   "/>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 59.0549, 491.613)" x="59.0549" y="491.613">0.00</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 282.662, 491.613)" x="282.662" y="491.613">0.25</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 506.269, 491.613)" x="506.269" y="491.613">0.50</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 729.875, 491.613)" x="729.875" y="491.613">0.75</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 953.482, 491.613)" x="953.482" y="491.613">1.00</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 464.089)" x="22.2221" y="464.089">0.0</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 393.12)" x="22.2221" y="393.12">0.2</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 322.152)" x="22.2221" y="322.152">0.4</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 251.183)" x="22.2221" y="251.183">0.6</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 180.214)" x="22.2221" y="180.214">0.8</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 109.246)" x="22.2221" y="109.246">1.0</text>
# </g>
# <g clip-path="url(#clip8900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 38.2769)" x="22.2221" y="38.2769">1.2</text>
# </g>
# <circle clip-path="url(#clip8902)" style="fill:#000000; stroke:none; fill-opacity:1" cx="59.0549" cy="459.623" r="4"/>
# <circle clip-path="url(#clip8902)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="59.0549" cy="459.623" r="3"/>
# <circle clip-path="url(#clip8902)" st

# %% [markdown]
# Define the problem:

# %%
using GeoStats

data = DataFrames.DataFrame(features=x, response=y)
geodata = GeoDataFrame(data, [:features])
domain = bounding_grid(geodata, [N])

problem = EstimationProblem(geodata, domain, :response)
# Out:
# 1D EstimationProblem
#   data:      100×2 GeoDataFrame (features)
#   domain:    100 RegularGrid{Float64,1}
#   variables: response (Float64)

# %% [markdown]
# # Solver options
#
# The user can specify the number of neighbors (default to all data locations), a kernel (or weight) function (default to `ExponentialKernel`), and a metric from the [Distances.jl](https://github.com/JuliaStats/Distances.jl) package (default to Euclidean).

# %%
using LocallyWeightedRegression

solver = LocalWeightRegress(
    :response => @NT(kernel=ExponentialKernel(10.))
)

solution = solve(problem, solver)
# Out:
# 1D EstimationSolution
#   domain: 100 RegularGrid{Float64,1}
#   variables: response

# %%
results = digest(solution)

yhat = results[:response][:mean]
yvar = results[:response][:variance]

scatter(x, y, label="data")
plot!(x, yhat, ribbon=yvar, fillalpha=.5, label="LWR")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="1000" height="500" viewBox="0 0 1000 500">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="1000" height="500"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9100)" points="
# 0,500 1000,500 1000,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="200" y="0" width="701" height="500"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9100)" points="
# 45.7332,477.923 980.315,477.923 980.315,11.811 45.7332,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="45" y="11" width="936" height="467"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   72.1836,470.931 72.1836,18.8027
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   292.604,470.931 292.604,18.8027
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   513.024,470.931 513.024,18.8027
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   733.444,470.931 733.444,18.8027
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   953.865,470.931 953.865,18.8027
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.7519,435.327 966.296,435.327
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.7519,372.256 966.296,372.256
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.7519,309.184 966.296,309.184
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.7519,246.113 966.296,246.113
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.7519,183.041 966.296,183.041
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.7519,119.97 966.296,119.97
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.7519,56.8987 966.296,56.8987
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,477.923 980.315,477.923
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,477.923 45.7332,11.811
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   72.1836,477.923 72.1836,470.931
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   292.604,477.923 292.604,470.931
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   513.024,477.923 513.024,470.931
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   733.444,477.923 733.444,470.931
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   953.865,477.923 953.865,470.931
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,435.327 59.7519,435.327
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,372.256 59.7519,372.256
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,309.184 59.7519,309.184
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,246.113 59.7519,246.113
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,183.041 59.7519,183.041
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,119.97 59.7519,119.97
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,56.8987 59.7519,56.8987
#   "/>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 72.1836, 493.723)" x="72.1836" y="493.723">0.00</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 292.604, 493.723)" x="292.604" y="493.723">0.25</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 513.024, 493.723)" x="513.024" y="493.723">0.50</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 733.444, 493.723)" x="733.444" y="493.723">0.75</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 953.865, 493.723)" x="953.865" y="493.723">1.00</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7332, 439.827)" x="35.7332" y="439.827">-0.25</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7332, 376.756)" x="35.7332" y="376.756">0.00</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7332, 313.684)" x="35.7332" y="313.684">0.25</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7332, 250.613)" x="35.7332" y="250.613">0.50</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7332, 187.541)" x="35.7332" y="187.541">0.75</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7332, 124.47)" x="35.7332" y="124.47">1.00</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7332, 61.3987)" x="35.7332" y="61.3987">1.25</text>
# </g>
# <circle clip-path="url(#clip9102)" style="fill:#000000; stroke:none; fill-opacity:1" cx="72.1836" cy="372.28" r="4"/>
# <circle clip-path="url(#clip9102)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="72.1836" cy="372.28" r="3"/>
# <circle clip-path="url(#clip910
