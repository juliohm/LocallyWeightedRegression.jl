# %% [markdown]
# # Problem definition
#
# Create some data, in this case a parabola plus white noise:

# %%
using Plots
gr(size=(1000,500))

srand(2017)

N = 100
x = linspace(0,1, N)
y = x.^2 .+ [i/1000*randn() for i=1:N]

scatter(x, y, label="data")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="1000" height="500" viewBox="0 0 1000 500">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="1000" height="500"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0800)" points="
# 0,500 1000,500 1000,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="200" y="0" width="701" height="500"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0800)" points="
# 32.2221,475.813 980.315,475.813 980.315,11.811 32.2221,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="32" y="11" width="949" height="465"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.0549,468.853 59.0549,18.7711
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   282.662,468.853 282.662,18.7711
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   506.269,468.853 506.269,18.7711
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   729.875,468.853 729.875,18.7711
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   953.482,468.853 953.482,18.7711
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.4435,459.589 966.094,459.589
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.4435,388.62 966.094,388.62
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.4435,317.652 966.094,317.652
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.4435,246.683 966.094,246.683
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.4435,175.714 966.094,175.714
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.4435,104.746 966.094,104.746
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.4435,33.7769 966.094,33.7769
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,475.813 980.315,475.813
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,475.813 32.2221,11.811
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   59.0549,475.813 59.0549,468.853
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   282.662,475.813 282.662,468.853
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   506.269,475.813 506.269,468.853
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   729.875,475.813 729.875,468.853
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   953.482,475.813 953.482,468.853
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,459.589 46.4435,459.589
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,388.62 46.4435,388.62
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,317.652 46.4435,317.652
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,246.683 46.4435,246.683
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,175.714 46.4435,175.714
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,104.746 46.4435,104.746
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,33.7769 46.4435,33.7769
#   "/>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 59.0549, 491.613)" x="59.0549" y="491.613">0.00</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 282.662, 491.613)" x="282.662" y="491.613">0.25</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 506.269, 491.613)" x="506.269" y="491.613">0.50</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 729.875, 491.613)" x="729.875" y="491.613">0.75</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 953.482, 491.613)" x="953.482" y="491.613">1.00</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 464.089)" x="22.2221" y="464.089">0.0</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 393.12)" x="22.2221" y="393.12">0.2</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 322.152)" x="22.2221" y="322.152">0.4</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 251.183)" x="22.2221" y="251.183">0.6</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 180.214)" x="22.2221" y="180.214">0.8</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 109.246)" x="22.2221" y="109.246">1.0</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 38.2769)" x="22.2221" y="38.2769">1.2</text>
# </g>
# <circle clip-path="url(#clip0802)" style="fill:#000000; stroke:none; fill-opacity:1" cx="59.0549" cy="459.623" r="4"/>
# <circle clip-path="url(#clip0802)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="59.0549" cy="459.623" r="3"/>
# <circle clip-path="url(#clip0802)" st

# %% [markdown]
# Define the problem:

# %%
using GeoStats

data = DataFrames.DataFrame(features=x, response=y)
geodata = GeoDataFrame(data, [:features])
domain = bounding_grid(geodata, [N])

problem = EstimationProblem(geodata, domain, :response)
# Out:
# 1D EstimationProblem
#   data:      100×2 GeoDataFrame (features)
#   domain:    100 RegularGrid{Float64,1}
#   variables: response (Float64)

# %% [markdown]
# # Solver options
#
# The user can specify the number of neighbors (default to all data locations), a kernel (or weight) function (default to `ExponentialKernel`), and a metric from the [Distances.jl](https://github.com/JuliaStats/Distances.jl) package (default to Euclidean).

# %%
using LocallyWeightedRegression

solver = LocalWeightRegress(
    :response => @NT(kernel=ExponentialKernel(10.))
)

solution = solve(problem, solver)

plt = plot(solution)
scatter!(plt[1], x, y)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="1000" height="500" viewBox="0 0 1000 500">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="1000" height="500"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1000)" points="
# 0,500 1000,500 1000,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="200" y="0" width="701" height="500"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1000)" points="
# 32.2221,477.923 477.02,477.923 477.02,31.4961 32.2221,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="32" y="31" width="446" height="447"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.8107,471.227 44.8107,38.1925
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   149.716,471.227 149.716,38.1925
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   254.621,471.227 254.621,38.1925
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   359.526,471.227 359.526,38.1925
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   464.432,471.227 464.432,38.1925
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8941,459.161 470.348,459.161
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8941,391.395 470.348,391.395
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8941,323.629 470.348,323.629
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8941,255.864 470.348,255.864
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8941,188.098 470.348,188.098
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8941,120.332 470.348,120.332
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8941,52.5659 470.348,52.5659
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,477.923 477.02,477.923
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,477.923 32.2221,31.4961
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.8107,477.923 44.8107,471.227
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   149.716,477.923 149.716,471.227
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   254.621,477.923 254.621,471.227
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   359.526,477.923 359.526,471.227
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   464.432,477.923 464.432,471.227
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,459.161 38.8941,459.161
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,391.395 38.8941,391.395
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,323.629 38.8941,323.629
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,255.864 38.8941,255.864
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,188.098 38.8941,188.098
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,120.332 38.8941,120.332
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,52.5659 38.8941,52.5659
#   "/>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 44.8107, 493.723)" x="44.8107" y="493.723">0.00</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 149.716, 493.723)" x="149.716" y="493.723">0.25</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 254.621, 493.723)" x="254.621" y="493.723">0.50</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 359.526, 493.723)" x="359.526" y="493.723">0.75</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 464.432, 493.723)" x="464.432" y="493.723">1.00</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 463.661)" x="22.2221" y="463.661">0.0</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 395.895)" x="22.2221" y="395.895">0.2</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 328.129)" x="22.2221" y="328.129">0.4</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 260.364)" x="22.2221" y="260.364">0.6</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 192.598)" x="22.2221" y="192.598">0.8</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 124.832)" x="22.2221" y="124.832">1.0</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 22.2221, 57.0659)" x="22.2221" y="57.0659">1.2</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 254.621, 18)" x="254.621" y="18">response mean</text>
# </g>
# <polyline clip-path="url(
